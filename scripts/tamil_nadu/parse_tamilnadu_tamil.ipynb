# %%
import os
import pdf2image
from PIL import Image
import pytesseract
import difflib
import re
import pandas as pd
import sys
sys.path.append('../')
from helper import *

# %%
DATA_PATH = '../../data/'
STATE = 'tamilnadu/'

PARSE_DATA_PAGES = "../../parseData/images/"+STATE
create_path(PARSE_DATA_PAGES)

PARSE_DATA_BLOCKS = "../../parseData/blocks/"+STATE
create_path(PARSE_DATA_BLOCKS)

PARSE_DATA_CSVS = "../../parseData/csvs/"+STATE
create_path(PARSE_DATA_CSVS)

COLUMNS = ["number","id", "elector_name", "father_or_husband_name", "relationship", "house_no", "age", "sex", "ac_name", "parl_constituency", "part_no", "year", "state", "filename", "main_town", "police_station", "mandal", "revenue_division", "district", "pin_code", "polling_station_name", "polling_station_address", "net_electors_male", "net_electors_female", "net_electors_third_gender", "net_electors_total"]

state_pdfs_path = DATA_PATH+STATE
state_pdfs_files = os.listdir(state_pdfs_path)

# %%
sort_nicely(state_pdfs_files)
state_pdfs_files
# Out:
# ['.DS_Store',
#  'dt1_ac001_ac001126.pdf',
#  'dt1_ac001_ac001133.pdf',
#  'dt1_ac001_ac001140.pdf',
#  'dt1_ac002_ac002082.pdf',
#  'dt1_ac002_ac002099.pdf',
#  'dt1_ac002_ac002270.pdf',
#  'dt1_ac002_ac002287.pdf',
#  'dt1_ac003_ac003019.pdf',
#  'dt1_ac003_ac003026.pdf',
#  'dt1_ac003_ac003033.pdf',
#  'dt1_ac003_ac003214.pdf',
#  'dt1_ac003_ac003221.pdf',
#  'dt1_ac003_ac003238.pdf',
#  'dt1_ac004_ac004163.pdf',
#  'dt1_ac004_ac004170.pdf',
#  'dt1_ac004_ac004187.pdf',
#  'dt1_ac005_ac005107.pdf',
#  'dt1_ac005_ac005114.pdf',
#  'dt1_ac005_ac005121.pdf',
#  'dt1_ac005_ac005302.pdf',
#  'dt1_ac006_ac006056.pdf',
#  'dt1_ac006_ac006063.pdf',
#  'dt1_ac006_ac006070.pdf',
#  'dt1_ac006_ac006244.pdf',
#  'dt1_ac006_ac006251.pdf',
#  'dt1_ac007_ac007007.pdf',
#  'dt1_ac007_ac007014.pdf',
#  'dt1_ac007_ac007193.pdf',
#  'dt1_ac008_ac008137.pdf',
#  'dt1_ac008_ac008144.pdf',
#  'dt1_ac008_ac008151.pdf',
#  'dt1_ac009_ac009086.pdf',
#  'dt1_ac009_ac009093.pdf',
#  'dt1_ac009_ac009274.pdf',
#  'dt1_ac009_ac009281.pdf',
#  'dt1_ac009_ac009298.pdf',
#  'dt1_ac010_ac010110.pdf',
#  'dt1_ac010_ac010127.pdf',
#  'dt2_ac011_ac011146.pdf',
#  'dt2_ac011_ac011153.pdf',
#  'dt2_ac011_ac011160.pdf',
#  'dt2_ac012_ac012283.pdf',
#  'dt2_ac013_ac013039.pdf',
#  'dt2_ac013_ac013046.pdf',
#  'dt2_ac014_ac014176.pdf',
#  'dt2_ac014_ac014183.pdf',
#  'dt2_ac014_ac014190.pdf',
#  'dt2_ac015_ac015110.pdf',
#  'dt2_ac015_ac015127.pdf',
#  'dt2_ac015_ac015134.pdf',
#  'dt2_ac016_ac016069.pdf',
#  'dt2_ac016_ac016076.pdf',
#  'dt2_ac016_ac016083.pdf',
#  'dt2_ac017_ac017003.pdf',
#  'dt2_ac017_ac017010.pdf',
#  'dt2_ac017_ac017027.pdf',
#  'dt2_ac018_ac018140.pdf',
#  'dt2_ac018_ac018157.pdf',
#  'dt2_ac018_ac018164.pdf',
#  'dt2_ac019_ac019108.pdf',
#  'dt2_ac020_ac020130.pdf',
#  'dt2_ac020_ac020147.pdf',
#  'dt2_ac021_ac021089.pdf',
#  'dt2_ac021_ac021096.pdf',
#  'dt2_ac022_ac022016.pdf',
#  'dt2_ac022_ac022023.pdf',
#  'dt2_ac022_ac022030.pdf',
#  'dt2_ac022_ac022204.pdf',
#  'dt2_ac022_ac022211.pdf',
#  'dt2_ac022_ac022228.pdf',
#  'dt2_ac023_ac023153.pdf',
#  'dt2_ac023_ac023160.pdf',
#  'dt2_ac023_ac023177.pdf',
#  'dt2_ac024_ac024104.pdf',
#  'dt2_ac024_ac024111.pdf',
#  'dt2_ac025_ac025046.pdf',
#  'dt2_ac025_ac025053.pdf',
#  'dt2_ac025_ac025060.pdf',
#  'dt2_ac025_ac025234.pdf',
#  'dt2_ac025_ac025241.pdf',
#  'dt2_ac026_ac026004.pdf',
#  'dt2_ac026_ac026190.pdf',
#  'dt3_ac027_ac027016.pdf',
#  'dt3_ac027_ac027023.pdf',
#  'dt3_ac027_ac027030.pdf',
#  'dt3_ac027_ac027204.pdf',
#  'dt3_ac027_ac027211.pdf',
#  'dt3_ac027_ac027228.pdf',
#  'dt3_ac027_ac027409.pdf',
#  'dt3_ac027_ac027416.pdf',
#  'dt3_ac028_ac028160.pdf',
#  'dt3_ac028_ac028177.pdf',
#  'dt3_ac028_ac028358.pdf',
#  'dt3_ac028_ac028365.pdf',
#  'dt3_ac028_ac028372.pdf',
#  'dt3_ac029_ac029104.pdf',
#  'dt3_ac029_ac029111.pdf',
#  'dt3_ac029_ac029309.pdf',
#  'dt3_ac030_ac030143.pdf',
#  'dt3_ac030_ac030150.pdf',
#  'dt3_ac030_ac030167.pdf',
#  'dt3_ac030_ac030324.pdf',
#  'dt3_ac030_ac030331.pdf',
#  'dt3_ac030_ac030348.pdf',
#  'dt3_ac031_ac031092.pdf',
#  'dt3_ac031_ac031280.pdf',
#  'dt3_ac031_ac031297.pdf',
#  'dt3_ac032_ac032036.pdf',
#  'dt3_ac032_ac032043.pdf',
#  'dt3_ac032_ac032050.pdf',
#  'dt3_ac032_ac032217.pdf',
#  'dt3_ac032_ac032224.pdf',
#  'dt3_ac032_ac032231.pdf',
#  'dt3_ac032_ac032405.pdf',
#  'dt3_ac032_ac032412.pdf',
#  'dt3_ac033_ac033166.pdf',
#  'dt3_ac033_ac033173.pdf',
#  'dt3_ac033_ac033180.pdf',
#  'dt3_ac034_ac034117.pdf',
#  'dt3_ac034_ac034124.pdf',
#  'dt3_ac035_ac035059.pdf',
#  'dt3_ac035_ac035066.pdf',
#  'dt3_ac035_ac035073.pdf',
#  'dt3_ac035_ac035254.pdf',
#  'dt3_ac035_ac035261.pdf',
#  'dt3_ac036_ac036017.pdf',
#  'dt3_ac036_ac036205.pdf',
#  'dt3_ac037_ac037147.pdf',
#  'dt3_ac037_ac037154.pdf',
#  'dt3_ac037_ac037161.pdf',
#  'dt4_ac038_ac038173.pdf',
#  'dt4_ac038_ac038180.pdf',
#  'dt4_ac038_ac038197.pdf',
#  'dt4_ac039_ac039117.pdf',
#  'dt4_ac039_ac039124.pdf',
#  'dt4_ac040_ac040156.pdf',
#  'dt4_ac040_ac040163.pdf',
#  'dt4_ac040_ac040170.pdf',
#  'dt4_ac041_ac041107.pdf',
#  'dt4_ac042_ac042049.pdf',
#  'dt4_ac042_ac042056.pdf',
#  'dt4_ac042_ac042063.pdf',
#  'dt4_ac042_ac042237.pdf',
#  'dt4_ac042_ac042244.pdf',
#  'dt4_ac043_ac043007.pdf',
#  'dt4_ac043_ac043186.pdf',
#  'dt4_ac043_ac043193.pdf',
#  'dt4_ac044_ac044120.pdf',
#  'dt4_ac044_ac044137.pdf',
#  'dt4_ac045_ac045079.pdf',
#  'dt4_ac045_ac045086.pdf',
#  'dt4_ac046_ac046013.pdf',
#  'dt4_ac046_ac046020.pdf',
#  'dt4_ac046_ac046201.pdf',
#  'dt4_ac046_ac046218.pdf',
#  'dt4_ac046_ac046225.pdf',
#  'dt4_ac047_ac047150.pdf',
#  'dt4_ac047_ac047167.pdf',
#  'dt4_ac047_ac047174.pdf',
#  'dt4_ac048_ac048101.pdf',
#  'dt4_ac048_ac048118.pdf',
#  'dt4_ac049_ac049043.pdf',
#  'dt4_ac049_ac049050.pdf',
#  'dt4_ac049_ac049067.pdf',
#  'dt4_ac049_ac049231.pdf',
#  'dt4_ac049_ac049248.pdf',
#  'dt4_ac049_ac049255.pdf',
#  'dt4_ac050_ac050082.pdf',
#  'dt4_ac050_ac050099.pdf',
#  'dt5_ac051_ac051103.pdf',
#  'dt5_ac051_ac051110.pdf',
#  'dt5_ac051_ac051127.pdf',
#  'dt5_ac052_ac052052.pdf',
#  'dt5_ac052_ac052069.pdf',
#  'dt5_ac052_ac052076.pdf',
#  'dt5_ac052_ac052240.pdf',
#  'dt5_ac052_ac052257.pdf',
#  'dt5_ac053_ac053003.pdf',
#  'dt5_ac053_ac053010.pdf',
#  'dt5_ac053_ac053199.pdf',
#  'dt5_ac054_ac054133.pdf',
#  'dt5_ac054_ac054140.pdf',
#  'dt5_ac055_ac055082.pdf',
#  'dt5_ac055_ac055099.pdf',
#  'dt5_ac055_ac055287.pdf',
#  'dt5_ac055_ac055294.pdf',
#  'dt5_ac056_ac056026.pdf',
#  'dt5_ac056_ac056033.pdf',
#  'dt5_ac056_ac056040.pdf',
#  'dt5_ac056_ac056214.pdf',
#  'dt5_ac056_ac056221.pdf',
#  'dt5_ac056_ac056238.pdf',
#  'dt6_ac057_ac057052.pdf',
#  'dt6_ac057_ac057069.pdf',
#  'dt6_ac057_ac057076.pdf',
#  'dt6_ac058_ac058003.pdf',
#  'dt6_ac058_ac058010.pdf',
#  'dt6_ac058_ac058199.pdf',
#  'dt6_ac058_ac058208.pdf',
#  'dt6_ac059_ac059140.pdf',
#  'dt6_ac059_ac059157.pdf',
#  'dt6_ac060_ac060172.pdf',
#  'dt6_ac060_ac060189.pdf',
#  'dt6_ac060_ac060196.pdf',
#  'dt6_ac061_ac061116.pdf',
#  'dt6_ac061_ac061123.pdf',
#  'dt6_ac061_ac061130.pdf',
#  'dt7_ac062_ac062142.pdf',
#  'dt7_ac062_ac062159.pdf',
#  'dt7_ac062_ac062166.pdf',
#  'dt7_ac063_ac063100.pdf',
#  'dt7_ac063_ac063289.pdf',
#  'dt7_ac064_ac064035.pdf',
#  'dt7_ac064_ac064042.pdf',
#  'dt7_ac064_ac064059.pdf',
#  'dt7_ac064_ac064223.pdf',
#  'dt7_ac064_ac064230.pdf',
#  'dt7_ac064_ac064247.pdf',
#  'dt7_ac065_ac065172.pdf',
#  'dt7_ac065_ac065189.pdf',
#  'dt7_ac065_ac065196.pdf',
#  'dt7_ac066_ac066116.pdf',
#  'dt7_ac066_ac066123.pdf',
#  'dt7_ac066_ac066130.pdf',
#  'dt7_ac067_ac067065.pdf',
#  'dt7_ac067_ac067072.pdf',
#  'dt7_ac067_ac067089.pdf',
#  'dt7_ac067_ac067260.pdf',
#  'dt7_ac067_ac067277.pdf',
#  'dt7_ac068_ac068009.pdf',
#  'dt7_ac068_ac068016.pdf',
#  'dt7_ac068_ac068023.pdf',
#  'dt7_ac068_ac068204.pdf',
#  'dt7_ac068_ac068211.pdf',
#  'dt7_ac068_ac068235.pdf',
#  'dt7_ac069_ac069153.pdf',
#  'dt7_ac069_ac069160.pdf',
#  'dt7_ac069_ac069177.pdf',
#  'dt8_ac070_ac070081.pdf',
#  'dt8_ac070_ac070098.pdf',
#  'dt8_ac070_ac070279.pdf',
#  'dt8_ac070_ac070286.pdf',
#  'dt8_ac071_ac071018.pdf',
#  'dt8_ac071_ac071025.pdf',
#  'dt8_ac071_ac071032.pdf',
#  'dt8_ac071_ac071206.pdf',
#  'dt8_ac071_ac071213.pdf',
#  'dt8_ac071_ac071220.pdf',
#  'dt8_ac072_ac072162.pdf',
#  'dt8_ac072_ac072179.pdf',
#  'dt8_ac073_ac073106.pdf',
#  'dt8_ac073_ac073113.pdf',
#  'dt8_ac074_ac074055.pdf',
#  'dt8_ac074_ac074062.pdf',
#  'dt8_ac074_ac074236.pdf',
#  'dt8_ac074_ac074243.pdf',
#  'dt8_ac074_ac074250.pdf',
#  'dt8_ac075_ac075006.pdf',
#  'dt8_ac075_ac075185.pdf',
#  'dt8_ac075_ac075192.pdf',
#  'dt8_ac076_ac076129.pdf',
#  'dt8_ac076_ac076136.pdf',
#  'dt8_ac076_ac076143.pdf',
#  'dt8_ac077_ac077078.pdf',
#  'dt8_ac077_ac077085.pdf',
#  'dt8_ac077_ac077092.pdf',
#  'dt8_ac077_ac077273.pdf',
#  'dt8_ac077_ac077280.pdf',
#  'dt8_ac077_ac077297.pdf',
#  'dt8_ac078_ac078012.pdf',
#  'dt8_ac078_ac078029.pdf',
#  'dt8_ac078_ac078036.pdf',
#  'dt8_ac078_ac078217.pdf',
#  'dt8_ac078_ac078224.pdf',
#  'dt8_ac078_ac078231.pdf',
#  'dt8_ac079_ac079166.pdf',
#  'dt8_ac079_ac079173.pdf',
#  'dt8_ac079_ac079180.pdf',
#  'dt8_ac080_ac080002.pdf',
#  'dt8_ac080_ac080019.pdf',
#  'dt8_ac080_ac080207.pdf',
#  'dt9_ac081_ac081038.pdf',
#  'dt9_ac081_ac081045.pdf',
#  'dt9_ac081_ac081052.pdf',
#  'dt9_ac081_ac081226.pdf',
#  'dt9_ac081_ac081233.pdf',
#  'dt9_ac081_ac081240.pdf',
#  'dt9_ac082_ac082175.pdf',
#  'dt9_ac082_ac082182.pdf',
#  'dt9_ac083_ac083119.pdf',
#  'dt9_ac083_ac083126.pdf',
#  'dt9_ac083_ac083307.pdf',
#  'dt9_ac084_ac084068.pdf',
#  'dt9_ac084_ac084075.pdf',
#  'dt9_ac084_ac084082.pdf',
#  'dt9_ac084_ac084249.pdf',
#  'dt9_ac084_ac084256.pdf',
#  'dt9_ac084_ac084263.pdf',
#  'dt9_ac085_ac085002.pdf',
#  'dt9_ac085_ac085019.pdf',
#  'dt9_ac085_ac085207.pdf',
#  'dt9_ac086_ac086149.pdf',
#  'dt9_ac086_ac086156.pdf',
#  'dt9_ac087_ac087098.pdf',
#  'dt9_ac087_ac087286.pdf',
#  'dt9_ac087_ac087293.pdf',
#  'dt9_ac088_ac088032.pdf',
#  'dt9_ac088_ac088049.pdf',
#  'dt9_ac088_ac088220.pdf',
#  'dt9_ac088_ac088237.pdf',
#  'dt9_ac088_ac088244.pdf',
#  'dt9_ac089_ac089179.pdf',
#  'dt9_ac089_ac089186.pdf',
#  'dt9_ac089_ac089193.pdf',
#  'dt9_ac090_ac090015.pdf',
#  'dt9_ac090_ac090022.pdf',
#  'dt9_ac090_ac090039.pdf',
#  'dt9_ac090_ac090203.pdf',
#  'dt9_ac090_ac090210.pdf',
#  'dt9_ac091_ac091152.pdf',
#  'dt9_ac091_ac091169.pdf',
#  'dt9_ac091_ac091176.pdf',
#  'dt10_ac092_ac092121.pdf',
#  'dt10_ac092_ac092138.pdf',
#  'dt10_ac092_ac092145.pdf',
#  'dt10_ac093_ac093070.pdf',
#  'dt10_ac093_ac093087.pdf',
#  'dt10_ac093_ac093094.pdf',
#  'dt10_ac093_ac093268.pdf',
#  'dt10_ac093_ac093275.pdf',
#  'dt10_ac094_ac094014.pdf',
#  'dt10_ac094_ac094021.pdf',
#  'dt10_ac094_ac094202.pdf',
#  'dt10_ac094_ac094219.pdf',
#  'dt10_ac095_ac095151.pdf',
#  'dt10_ac095_ac095168.pdf',
#  'dt10_ac096_ac096102.pdf',
#  'dt10_ac097_ac097044.pdf',
#  'dt10_ac097_ac097051.pdf',
#  'dt10_ac097_ac097068.pdf',
#  'dt10_ac097_ac097232.pdf',
#  'dt10_ac097_ac097249.pdf',
#  'dt10_ac097_ac097256.pdf',
#  'dt11_ac098_ac098070.pdf',
#  'dt11_ac098_ac098087.pdf',
#  'dt11_ac098_ac098094.pdf',
#  'dt11_ac099_ac099014.pdf',
#  'dt11_ac099_ac099021.pdf',
#  'dt11_ac099_ac099202.pdf',
#  'dt11_ac099_ac099219.pdf',
#  'dt11_ac099_ac099226.pdf',
#  'dt11_ac100_ac100124.pdf',
#  'dt11_ac100_ac100131.pdf',
#  'dt11_ac100_ac100148.pdf',
#  'dt11_ac103_ac103161.pdf',
#  'dt11_ac103_ac103178.pdf',
#  'dt11_ac103_ac103185.pdf',
#  'dt11_ac104_ac104105.pdf',
#  'dt11_ac104_ac104112.pdf',
#  'dt11_ac105_ac105054.pdf',
#  'dt11_ac105_ac105061.pdf',
#  'dt11_ac105_ac105078.pdf',
#  'dt11_ac105_ac105242.pdf',
#  'dt11_ac106_ac106005.pdf',
#  'dt11_ac106_ac106012.pdf',
#  'dt11_ac106_ac106191.pdf',
#  'dt11_ac107_ac107135.pdf',
#  'dt11_ac107_ac107142.pdf',
#  'dt12_ac108_ac108161.pdf',
#  'dt12_ac108_ac108178.pdf',
#  'dt12_ac108_ac108185.pdf',
#  'dt12_ac109_ac109105.pdf',
#  'dt12_ac109_ac109112.pdf',
#  'dt12_ac110_ac110144.pdf',
#  'dt12_ac110_ac110151.pdf',
#  'dt13_ac111_ac111170.pdf',
#  'dt13_ac111_ac111187.pdf',
#  'dt13_ac111_ac111194.pdf',
#  'dt13_ac116_ac116093.pdf',
#  'dt13_ac116_ac116102.pdf',
#  'dt13_ac116_ac116281.pdf',
#  'dt13_ac116_ac116298.pdf',
#  'dt13_ac117_ac117037.pdf',
#  'dt13_ac117_ac117044.pdf',
#  'dt13_ac117_ac117051.pdf',
#  'dt13_ac117_ac117225.pdf',
#  'dt13_ac117_ac117232.pdf',
#  'dt13_ac117_ac117249.pdf',
#  'dt13_ac118_ac118174.pdf',
#  'dt13_ac118_ac118181.pdf',
#  'dt13_ac118_ac118198.pdf',
#  'dt13_ac119_ac119118.pdf',
#  'dt13_ac119_ac119125.pdf',
#  'dt13_ac119_ac119132.pdf',
#  'dt13_ac120_ac120157.pdf',
#  'dt13_ac120_ac120164.pdf',
#  'dt13_ac120_ac120171.pdf',
#  'dt13_ac121_ac121108.pdf',
#  'dt13_ac121_ac121294.pdf',
#  'dt13_ac121_ac121303.pdf',
#  'dt13_ac122_ac122040.pdf',
#  'dt13_ac122_ac122057.pdf',
#  'dt13_ac122_ac122238.pdf',
#  'dt13_ac122_ac122245.pdf',
#  'dt13_ac122_ac122252.pdf',
#  'dt13_ac123_ac123187.pdf',
#  'dt13_ac123_ac123194.pdf',
#  'dt13_ac124_ac124121.pdf',
#  'dt13_ac124_ac124138.pdf',
#  'dt13_ac124_ac124145.pdf',
#  'dt14_ac127_ac127057.pdf',
#  'dt14_ac127_ac127064.pdf',
#  'dt14_ac127_ac127238.pdf',
#  'dt14_ac127_ac127245.pdf',
#  'dt14_ac127_ac127252.pdf',
#  'dt14_ac128_ac128008.pdf',
#  'dt14_ac128_ac128187.pdf',
#  'dt14_ac128_ac128194.pdf',
#  'dt14_ac129_ac129121.pdf',
#  'dt14_ac129_ac129138.pdf',
#  'dt14_ac129_ac129145.pdf',
#  'dt14_ac130_ac130160.pdf',
#  'dt14_ac130_ac130177.pdf',
#  'dt14_ac130_ac130184.pdf',
#  'dt14_ac131_ac131104.pdf',
#  'dt14_ac131_ac131111.pdf',
#  'dt14_ac132_ac132053.pdf',
#  'dt14_ac132_ac132060.pdf',
#  'dt14_ac132_ac132077.pdf',
#  'dt14_ac132_ac132258.pdf',
#  'dt14_ac132_ac132265.pdf',
#  'dt14_ac133_ac133004.pdf',
#  'dt14_ac133_ac133011.pdf',
#  'dt14_ac133_ac133209.pdf',
#  'dt15_ac134_ac134023.pdf',
#  'dt15_ac134_ac134030.pdf',
#  'dt15_ac134_ac134047.pdf',
#  'dt15_ac134_ac134228.pdf',
#  'dt15_ac134_ac134235.pdf',
#  'dt15_ac135_ac135177.pdf',
#  'dt15_ac135_ac135184.pdf',
#  'dt15_ac136_ac136111.pdf',
#  'dt15_ac136_ac136128.pdf',
#  'dt15_ac137_ac137060.pdf',
#  'dt15_ac137_ac137077.pdf',
#  'dt15_ac137_ac137258.pdf',
#  'dt16_ac138_ac138096.pdf',
#  'dt16_ac138_ac138284.pdf',
#  'dt16_ac138_ac138291.pdf',
#  'dt16_ac139_ac139030.pdf',
#  'dt16_ac139_ac139047.pdf',
#  'dt16_ac139_ac139054.pdf',
#  'dt16_ac139_ac139228.pdf',
#  'dt16_ac139_ac139235.pdf',
#  'dt16_ac140_ac140079.pdf',
#  'dt16_ac140_ac140086.pdf',
#  'dt16_ac140_ac140250.pdf',
#  'dt16_ac140_ac140267.pdf',
#  'dt16_ac141_ac141006.pdf',
#  'dt16_ac141_ac141013.pdf',
#  'dt16_ac141_ac141020.pdf',
#  'dt16_ac141_ac141201.pdf',
#  'dt16_ac141_ac141218.pdf',
#  'dt16_ac142_ac142143.pdf',
#  'dt16_ac142_ac142150.pdf',
#  'dt16_ac142_ac142167.pdf',
#  'dt16_ac143_ac143101.pdf',
#  'dt16_ac144_ac144036.pdf',
#  'dt16_ac144_ac144043.pdf',
#  'dt16_ac144_ac144050.pdf',
#  'dt16_ac144_ac144231.pdf',
#  'dt16_ac144_ac144248.pdf',
#  'dt16_ac145_ac145180.pdf',
#  'dt16_ac145_ac145197.pdf',
#  'dt16_ac146_ac146124.pdf',
#  'dt16_ac146_ac146131.pdf',
#  'dt17_ac147_ac147150.pdf',
#  'dt17_ac147_ac147167.pdf',
#  'dt17_ac147_ac147174.pdf',
#  'dt17_ac148_ac148101.pdf',
#  'dt17_ac148_ac148297.pdf',
#  'dt18_ac151_ac151103.pdf',
#  'dt18_ac151_ac151110.pdf',
#  'dt18_ac151_ac151127.pdf',
#  'dt18_ac152_ac152052.pdf',
#  'dt18_ac152_ac152069.pdf',
#  'dt18_ac152_ac152076.pdf',
#  'dt18_ac152_ac152240.pdf',
#  'dt18_ac152_ac152257.pdf',
#  'dt18_ac153_ac153003.pdf',
#  'dt18_ac153_ac153010.pdf',
#  'dt18_ac153_ac153199.pdf',
#  'dt18_ac154_ac154133.pdf',
#  'dt18_ac154_ac154140.pdf',
#  'dt18_ac155_ac155099.pdf',
#  'dt18_ac156_ac156026.pdf',
#  'dt18_ac156_ac156033.pdf',
#  'dt18_ac156_ac156214.pdf',
#  'dt18_ac156_ac156221.pdf',
#  'dt18_ac156_ac156238.pdf',
#  'dt18_ac157_ac157163.pdf',
#  'dt18_ac157_ac157170.pdf',
#  'dt18_ac157_ac157187.pdf',
#  'dt18_ac158_ac158107.pdf',
#  'dt18_ac158_ac158114.pdf',
#  'dt18_ac158_ac158121.pdf',
#  'dt19_ac160_ac160172.pdf',
#  'dt19_ac160_ac160189.pdf',
#  'dt19_ac160_ac160196.pdf',
#  'dt19_ac161_ac161116.pdf',
#  'dt19_ac161_ac161123.pdf',
#  'dt19_ac161_ac161130.pdf',
#  'dt19_ac162_ac162065.pdf',
#  'dt19_ac162_ac162072.pdf',
#  'dt19_ac162_ac162089.pdf',
#  'dt19_ac162_ac162260.pdf',
#  'dt19_ac163_ac163009.pdf',
#  'dt19_ac163_ac163016.pdf',
#  'dt19_ac163_ac163023.pdf',
#  'dt19_ac163_ac163204.pdf',
#  'dt19_ac163_ac163211.pdf',
#  'dt19_ac164_ac164153.pdf',
#  'dt19_ac164_ac164160.pdf',
#  'dt19_ac164_ac164177.pdf',
#  'dt20_ac166_ac166106.pdf',
#  'dt20_ac166_ac166113.pdf',
#  'dt20_ac166_ac166120.pdf',
#  'dt20_ac167_ac167055.pdf',
#  'dt20_ac167_ac167062.pdf',
#  'dt20_ac167_ac167079.pdf',
#  'dt20_ac167_ac167250.pdf',
#  'dt20_ac167_ac167267.pdf',
#  'dt20_ac168_ac168006.pdf',
#  'dt20_ac168_ac168013.pdf',
#  'dt20_ac168_ac168201.pdf',
#  'dt20_ac169_ac169143.pdf',
#  'dt20_ac169_ac169150.pdf',
#  'dt21_ac170_ac170064.pdf',
#  'dt21_ac170_ac170071.pdf',
#  'dt21_ac170_ac170088.pdf',
#  'dt21_ac170_ac170269.pdf',
#  'dt21_ac170_ac170276.pdf',
#  'dt21_ac171_ac171008.pdf',
#  'dt21_ac171_ac171015.pdf',
#  'dt21_ac171_ac171022.pdf',
#  'dt21_ac171_ac171203.pdf',
#  'dt21_ac171_ac171210.pdf',
#  'dt21_ac172_ac172152.pdf',
#  'dt21_ac172_ac172169.pdf',
#  'dt21_ac173_ac173103.pdf',
#  'dt21_ac173_ac173110.pdf',
#  'dt21_ac173_ac173282.pdf',
#  'dt21_ac174_ac174045.pdf',
#  'dt21_ac174_ac174052.pdf',
#  'dt21_ac174_ac174226.pdf',
#  'dt21_ac174_ac174233.pdf',
#  'dt21_ac174_ac174240.pdf',
#  'dt21_ac175_ac175010.pdf',
#  'dt21_ac175_ac175175.pdf',
#  'dt21_ac175_ac175182.pdf',
#  'dt21_ac175_ac175199.pdf',
#  'dt21_ac176_ac176119.pdf',
#  'dt21_ac176_ac176126.pdf',
#  'dt21_ac176_ac176133.pdf',
#  'dt21_ac177_ac177068.pdf',
#  'dt21_ac177_ac177075.pdf',
#  'dt21_ac177_ac177082.pdf',
#  'dt23_ac184_ac184135.pdf',
#  'dt23_ac184_ac184142.pdf',
#  'dt23_ac184_ac184323.pdf',
#  'dt23_ac184_ac184330.pdf',
#  'dt23_ac185_ac185084.pdf',
#  'dt23_ac185_ac185091.pdf',
#  'dt23_ac185_ac185272.pdf',
#  'dt23_ac185_ac185289.pdf',
#  'dt23_ac186_ac186028.pdf',
#  'dt23_ac186_ac186035.pdf',
#  'dt23_ac186_ac186042.pdf',
#  'dt23_ac186_ac186216.pdf',
#  'dt23_ac186_ac186223.pdf',
#  'dt23_ac187_ac187165.pdf',
#  'dt23_ac187_ac187172.pdf',
#  'dt25_ac198_ac198001.pdf',
#  'dt25_ac198_ac198018.pdf',
#  'dt25_ac198_ac198025.pdf',
#  'dt25_ac198_ac198206.pdf',
#  'dt25_ac198_ac198213.pdf',
#  'dt25_ac199_ac199148.pdf',
#  'dt25_ac199_ac199155.pdf',
#  'dt25_ac199_ac199162.pdf',
#  'dt25_ac200_ac200077.pdf',
#  'dt25_ac200_ac200084.pdf',
#  'dt25_ac200_ac200091.pdf',
#  'dt25_ac200_ac200265.pdf',
#  'dt25_ac200_ac200272.pdf',
#  'dt25_ac201_ac201011.pdf',
#  'dt25_ac201_ac201028.pdf',
#  'dt25_ac201_ac201209.pdf',
#  'dt25_ac201_ac201216.pdf',
#  'dt26_ac202_ac202047.pdf',
#  'dt26_ac202_ac202054.pdf',
#  'dt26_ac202_ac202061.pdf',
#  'dt26_ac202_ac202235.pdf',
#  'dt26_ac202_ac202242.pdf',
#  'dt26_ac203_ac203005.pdf',
#  'dt26_ac203_ac203184.pdf',
#  'dt26_ac203_ac203191.pdf',
#  'dt26_ac204_ac204128.pdf',
#  'dt26_ac204_ac204135.pdf',
#  'dt26_ac204_ac204142.pdf',
#  'dt26_ac205_ac205077.pdf',
#  'dt26_ac205_ac205084.pdf',
#  'dt26_ac205_ac205091.pdf',
#  'dt26_ac205_ac205265.pdf',
#  'dt26_ac205_ac205272.pdf',
#  'dt26_ac206_ac206011.pdf',
#  'dt26_ac206_ac206028.pdf',
#  'dt26_ac206_ac206209.pdf',
#  'dt26_ac206_ac206216.pdf',
#  'dt26_ac206_ac206223.pdf',
#  'dt26_ac207_ac207158.pdf',
#  'dt26_ac207_ac207165.pdf',
#  'dt26_ac207_ac207172.pdf',
#  'dt26_ac208_ac208109.pdf',
#  'dt26_ac208_ac208116.pdf',
#  'dt27_ac209_ac209128.pdf',
#  'dt27_ac209_ac209135.pdf',
#  'dt27_ac209_ac209142.pdf',
#  'dt27_ac210_ac210167.pdf',
#  'dt27_ac210_ac210174.pdf',
#  'dt27_ac210_ac210181.pdf',
#  'dt27_ac211_ac211101.pdf',
#  'dt27_ac211_ac211118.pdf',
#  'dt27_ac211_ac211125.pdf',
#  'dt27_ac211_ac211306.pdf',
#  'dt27_ac211_ac211313.pdf',
#  'dt27_ac212_ac212050.pdf',
#  'dt27_ac212_ac212067.pdf',
#  'dt27_ac212_ac212074.pdf',
#  'dt27_ac212_ac212248.pdf',
#  'dt27_ac212_ac212255.pdf',
#  'dt27_ac212_ac212262.pdf',
#  'dt28_ac213_ac213086.pdf',
#  'dt28_ac213_ac213093.pdf',
#  'dt28_ac214_ac214037.pdf',
#  'dt28_ac214_ac214044.pdf',
#  'dt28_ac214_ac214218.pdf',
#  'dt28_ac214_ac214225.pdf',
#  'dt28_ac214_ac214232.pdf',
#  'dt28_ac215_ac215167.pdf',
#  'dt28_ac215_ac215174.pdf',
#  'dt28_ac215_ac215181.pdf',
#  'dt28_ac216_ac216101.pdf',
#  'dt28_ac216_ac216118.pdf',
#  'dt28_ac216_ac216125.pdf',
#  'dt28_ac217_ac217050.pdf',
#  'dt28_ac217_ac217067.pdf',
#  'dt28_ac217_ac217074.pdf',
#  'dt28_ac218_ac218001.pdf',
#  'dt28_ac218_ac218018.pdf',
#  'dt28_ac218_ac218206.pdf',
#  'dt28_ac218_ac218213.pdf',
#  'dt29_ac219_ac219020.pdf',
#  'dt29_ac219_ac219037.pdf',
#  'dt29_ac219_ac219044.pdf',
#  'dt29_ac219_ac219225.pdf',
#  'dt29_ac219_ac219232.pdf',
#  'dt29_ac219_ac219256.pdf',
#  'dt29_ac220_ac220069.pdf',
#  'dt29_ac220_ac220076.pdf',
#  'dt29_ac220_ac220083.pdf',
#  'dt29_ac220_ac220257.pdf',
#  'dt29_ac220_ac220264.pdf',
#  'dt29_ac220_ac220271.pdf',
#  'dt29_ac221_ac221003.pdf',
#  'dt29_ac221_ac221010.pdf',
#  'dt29_ac221_ac221027.pdf',
#  'dt29_ac221_ac221208.pdf',
#  'dt29_ac221_ac221215.pdf',
#  'dt29_ac222_ac222157.pdf',
#  'dt29_ac222_ac222164.pdf',
#  'dt29_ac223_ac223108.pdf',
#  'dt29_ac223_ac223287.pdf',
#  'dt29_ac223_ac223294.pdf',
#  'dt29_ac224_ac224040.pdf',
#  'dt29_ac224_ac224057.pdf',
#  'dt29_ac224_ac224064.pdf',
#  'dt29_ac224_ac224221.pdf',
#  'dt29_ac224_ac224238.pdf',
#  'dt29_ac224_ac224245.pdf',
#  'dt29_ac225_ac225187.pdf',
#  'dt29_ac225_ac225194.pdf',
#  'dt29_ac226_ac226114.pdf',
#  'dt29_ac226_ac226121.pdf',
#  'dt29_ac226_ac226138.pdf',
#  'dt29_ac227_ac227063.pdf',
#  'dt29_ac227_ac227070.pdf',
#  'dt29_ac227_ac227087.pdf',
#  'dt29_ac227_ac227268.pdf',
#  'dt29_ac227_ac227275.pdf',
#  'dt29_ac227_ac227282.pdf',
#  'dt29_ac228_ac228007.pdf',
#  'dt29_ac228_ac228014.pdf',
#  'dt29_ac228_ac228021.pdf',
#  'dt29_ac228_ac228202.pdf',
#  'dt29_ac228_ac228219.pdf',
#  'dt31_ac149_ac149030.pdf',
#  'dt31_ac149_ac149047.pdf',
#  'dt31_ac149_ac149054.pdf',
#  'dt31_ac149_ac149228.pdf',
#  'dt31_ac149_ac149235.pdf',
#  'dt31_ac150_ac150079.pdf',
#  'dt31_ac150_ac150086.pdf',
#  'dt31_ac150_ac150267.pdf',
#  'dt31_ac150_ac150274.pdf',
#  'dt31_ac150_ac150281.pdf',
#  'dt32_ac101_ac101077.pdf',
#  'dt32_ac101_ac101084.pdf',
#  'dt32_ac101_ac101091.pdf',
#  'dt32_ac101_ac101265.pdf',
#  'dt32_ac101_ac101272.pdf',
#  'dt32_ac102_ac102011.pdf',
#  'dt32_ac102_ac102028.pdf',
#  'dt32_ac102_ac102035.pdf',
#  'dt32_ac102_ac102209.pdf',
#  'dt32_ac102_ac102216.pdf',
#  'dt32_ac102_ac102223.pdf',
#  'dt32_ac112_ac112135.pdf',
#  'dt32_ac112_ac112142.pdf',
#  'dt32_ac112_ac112159.pdf',
#  'dt32_ac113_ac113084.pdf',
#  'dt32_ac113_ac113091.pdf',
#  'dt32_ac113_ac113289.pdf',
#  'dt32_ac113_ac113296.pdf',
#  'dt32_ac114_ac114028.pdf',
#  'dt32_ac114_ac114035.pdf',
#  'dt32_ac114_ac114042.pdf',
#  'dt32_ac114_ac114223.pdf',
#  'dt32_ac115_ac115172.pdf',
#  'dt32_ac115_ac115189.pdf',
#  'dt32_ac115_ac115360.pdf',
#  'dt32_ac115_ac115377.pdf',
#  'dt32_ac125_ac125100.pdf',
#  'dt32_ac126_ac126042.pdf',
#  'dt32_ac126_ac126059.pdf',
#  'dt32_ac126_ac126230.pdf',
#  'dt32_ac126_ac126247.pdf']

# %%
def get_mandal(a,b,c,d,img,crop_path):
            
    crop_img = crop_section(a,b,c,d,img)

    crop_det_path = crop_path+"det.jpg"
    crop_img.save(crop_det_path)

    text = (pytesseract.image_to_string(crop_det_path, config='--psm 6', lang='eng+tam'))
    text = text.split('\n')
    text = [ i for i in text if i!='' and i!='\x0c']

    return text
    
def get_stats(a,b,c,d,img,crop_path):

    crop_img = crop_section(a,b,c,d,img)

    crop_path = input_images_blocks_path+"page/"
    create_path(crop_path)

    crop_stat_path = crop_path+"stat.jpg"
    crop_img.save(crop_stat_path)

    a_n,b_n,c_n,d_n = extract_4_numbers(crop_stat_path)

    return a_n,b_n,c_n,d_n

def get_police_det(a,b,c,d,img,crop_path):

    crop_img = crop_section(a,b,c,d,img)

    crop_police_path = crop_path+"police.jpg"
    crop_img.save(crop_police_path)

    text = (pytesseract.image_to_string(crop_police_path, config='--psm 6', lang='eng+tam')) #config='--psm 4' config='-c preserve_interword_spaces=1'
    text = text.split('\n')
    text = [ i for i in text if i!='' and i!='\x0c']

    return text

def get_stats(a,b,c,d,img,crop_path):

    crop_img = crop_section(a,b,c,d,img)

    crop_path = input_images_blocks_path+"page/"
    create_path(crop_path)

    crop_stat_path = crop_path+"stat.jpg"
    crop_img.save(crop_stat_path)

    a_n,b_n,c_n,d_n = extract_4_numbers(crop_stat_path)

    return a_n,b_n,c_n,d_n

def extract_4_numbers(crop_stat_path):
    
    text = (pytesseract.image_to_string(crop_stat_path, config='--psm 11', lang='eng')) #config='--psm 4' config='-c preserve_interword_spaces=1'
#     print(text)
    text = re.findall(r'\d+', text)
#     print(text)

    if len(text)==4:
        if int(text[0]) + int(text[1]) == int(text[2]):
            net_electors_male,net_electors_female,net_electors_third_gender,net_electors_total = text[0],text[1],"0",text[2]
        elif int(text[0]) + int(text[1]) == int(text[3]):
            net_electors_male,net_electors_female,net_electors_third_gender,net_electors_total = text[0],text[1],"0",text[3]
        else:
            net_electors_male,net_electors_female,net_electors_third_gender,net_electors_total = text[0],text[1],text[2],text[3]
    elif len(text) == 3 and int(text[2])>=int(text[1]) and int(text[2])>=int(text[0]):
        net_electors_male,net_electors_female,net_electors_third_gender,net_electors_total = text[0],text[1],"0",text[2]
    elif len(text) == 2 and int(text[0])*2-100<int(text[1]):
        net_electors_male,net_electors_female,net_electors_third_gender,net_electors_total = text[0],int(text[1])-int(text[0]),"0",text[1]
    else:
        net_electors_male,net_electors_female,net_electors_third_gender,net_electors_total = "","","",""
    
    return net_electors_male,net_electors_female,net_electors_third_gender,net_electors_total

# %%
def split_data(data):
    seps = [":",">","-","."]
    
    for s in seps:
        if s in data:
            break

    data = data.split(s)
    data = [ i for i in data if i.strip()!='']
    if len(data)>1:
        data = data[1].strip()
        return data
    else:
        data = ""

# %%
def extract_name(name):
    
    row = name.split(":")
    if len(row)!=2:
        return ""
    else:
        return row[1].strip()
    
def extract_vid(v_id):
    row = v_id.split("|")
    if len(row)>=2:
        number = re.findall(r'\d+', row[0].strip())
        if len(number)>0:
            return number[0],row[1]
        else:
            return "",row[1]
        
    row = v_id.split(" ")
    if len(row)>=2:
        number = re.findall(r'\d+', row[0].strip())
        if len(number)>0:
            return number[0],row[1].strip()
        else:
            return "",row[1].strip()
    
    else:
        return "",v_id.strip()

def extract_house_no(house_no):
    row = house_no.split(":")
    if len(row)==2:
        house_no = row[1].strip()
        return house_no
    else:
        house_no = re.findall(r'\d+', row[0].strip())
        if len(house_no)>0:
            return house_no[0]
        else:
            return ""
    
def extract_age_gender(age_gender):
    
    text = re.findall(r'\d+', age_gender)
    
    if len(text)>0:
        age = text[0]
    else:
        age = ""
        
    if "ஆண்" in age_gender:
        gender = "Male"
    elif "பெண்" in age_gender:
        gender =  "Female" 
    else:
        gender = 'Male'
        
    return age, gender

def extract_rel_name(rel_name):
    row = rel_name.split(":")
    if len(row)==2:
        
        rel_type = extract_rel_type(row[0].strip())
        
        return row[1].strip(),rel_type
        
    else:
        row = rel_name.split(";")
        if len(row)!=2:
            return "",""
        else:
            rel_type = extract_rel_type(row[0].strip())
            return row[1].strip(),rel_type
        
    
def extract_rel_type(rel_type):
    
    if "கணவர்" in rel_type:
        rel_type = 'husband'
    elif 'தந்' in rel_type :
        rel_type = 'father'
    else:
        rel_type = 'father'
    
    return rel_type 


def extract_details_from_block(block):
    
    if len(block) == 5:
        v_id = block[0]
        name = block[1]
        rel_name = block[2]
        house_no = block[3]
        age_gender = block[4]
    else:
        v_id = block[0]
        name = block[1]+" "+ block[2]
        rel_name = block[3]
        house_no = block[4]
        age_gender = block[5]
    
    name = extract_name(name)
    rel_name,rel_type = extract_rel_name(rel_name)
    house_no = extract_house_no(house_no)
    age, gender = extract_age_gender(age_gender)
    number,voter_id = extract_vid(v_id)
    
    
    return [name,rel_name,rel_type,house_no,age,gender,voter_id,number]

def arrange_columns(first_page_list,block_list,filename,a_n,b_n,c_n,d_n):
    
    year = 2018
    state = 'tamilnadu'
    
    ac_name,parl_constituency,part_no,main_town,police_station,polling_station_name,polling_station_address,revenue_division,mandal,district,pin_code,net_electors_male,net_electors_female,net_electors_third_gender,net_electors_total = first_page_list
    name,rel_name,rel_type,house_no,age,gender,voter_id,number = block_list
    
    if net_electors_male =="" and net_electors_female=="":
        net_electors_male,net_electors_female,net_electors_third_gender,net_electors_total = a_n,b_n,c_n,d_n
    
    final_list = [number,voter_id,name,rel_name,rel_type,house_no,age,gender,ac_name,
                 parl_constituency,part_no,year,state,filename,main_town,police_station,mandal,
                 revenue_division,district,pin_code,polling_station_name,polling_station_address,
                 net_electors_male,net_electors_female,net_electors_third_gender,net_electors_total]


    return final_list

# %%
def generate_poll_blocks_from_page(page_full_path,page_blocks_path,amend_page, height):
    
    img = Image.open(page_full_path)
    
    def generate(intial_width,a,b,gap):
        count = 0
        crop_width = 1245
        crop_height = 481

        for col in range(1,11):

            for row in range(1,4):
                c = a+crop_width
                d = b+crop_height
                area = (a, b, c, d)
                cropped_img = img.crop(area)
                count = count+1
                cropped_img.save(page_blocks_path+str(count)+".jpg")

                a = c

            a = intial_width
            b = b+crop_height+gap
    
    intial_width = 290
    generate(intial_width,intial_width,height,0)

# %%
def extract_first_page_details(path):
    
    img = Image.open(path)
    
    crop_path = input_images_blocks_path+"page/"
    create_path(crop_path)
    
    a,b,c,d = 2156,4444,1490,148  # stats for male and female

    a_n,b_n,c_n,d_n = "","","",""
    a_n,b_n,c_n,d_n = get_stats(a,b,c,d,img,crop_path)
        
    a,b,c,d = 1062,3322,1200,644 # police name name and address
    
    text = get_police_det(a,b,c,d,img,crop_path)
    
    polling_station_name, polling_station_address = "",""

    
    if len(text) >=5:
        pass
    
    elif len(text)>1:
        idx = int(len(text)/2)
    
        psn,psa = text[:idx], text[idx:]

        for p in psn:
            polling_station_name = polling_station_name +" " +p
        for p in psa:
            polling_station_address = polling_station_address +" " +p
            
        polling_station_name = polling_station_name.strip()
        polling_station_address = polling_station_address.strip()
    
    a,b,c,d = 3073,2180,701,960  # mandal block
    main_town,police_station,revenue_division,mandal,district,pin_code = "","","","","",""

    text = get_mandal(a,b,c,d,img,crop_path)
    
    if len(text) == 7:

        main_town = text[0]
        police_station = text[3]
        revenue_division = text[1]
        mandal = text[4]
        district = text[5]
        pin_code = text[6]

    elif len(text) == 5:

        main_town = ""
        police_station = text[0]
        revenue_division = text[1]
        mandal = text[2]
        district = text[3]
        pin_code = text[4]
    
    elif len(text) == 6:

        main_town = text[0]
        police_station = text[2]
        revenue_division = text[1]
        mandal = text[3]
        district = text[4]
        pin_code = text[5]
    
    elif len(text) == 4:

        main_town = text[0]
        police_station = ""
        revenue_division = ""
        mandal = text[1]
        district = text[2]
        pin_code = text[3]

    
    a,b,c,d = 3378,422,380,200 # part no
    crop_img = crop_section(a,b,c,d,img)
    
    crop_part_path = crop_path+"part.jpg"
    crop_img.save(crop_part_path)

    text = (pytesseract.image_to_string(crop_part_path, config='--psm 6', lang='eng+tam')) #config='--psm 4' config='-c preserve_interword_spaces=1'
    text = re.findall(r'\d+', text)
            
    
    if len(text)>0:
        part_no = text[0]
    else:
        part_no = ""
        
    
    a,b,c,d = 352,417,2700,542 # ac name and parl
    crop_img = crop_section(a,b,c,d,img)
    
    crop_ac_path = crop_path+"ac.jpg"
    crop_img.save(crop_ac_path)
    
    text = (pytesseract.image_to_string(crop_ac_path, config='--psm 6', lang='tam')) #config='--psm 4' config='-c preserve_interword_spaces=1'
    text = text.split('\n')
    text = [ i for i in text if i!='' and i!='\x0c']
    
    ac_name,parl_constituency = '',''
    
    if len(text) >= 5:
        
        an = text[0].split('மற்றும்')
        if len(an)>0:
            ac_name = an[-1]
        
        pc = text[2].split('அடங்கியுள்ள')
        
        if len(pc)>1:
            parl_constituency = pc[1]
        else:
            pc = text[2].split('வணகயில்')
        
            if len(pc)>1:
                parl_constituency = pc[1]
            else:
                pc = text[2].split("பங்கய ப")
                if len(pc)>0:
                    parl_constituency = pc[-1]
        
        ac_name = ac_name.strip()
        parl_constituency = parl_constituency.strip()
        
   
    return [ac_name,parl_constituency,part_no,main_town,police_station,polling_station_name,polling_station_address,revenue_division,mandal,district,pin_code,a_n,b_n,c_n,d_n]

# %%
for pdf_file_name in ['dt3_ac036_ac036205.pdf']:
# for pdf_file_name in state_pdfs_files:
    
    print(pdf_file_name)
    
    #create images,blocks and csvs paths for each file
    pdf_file_name_without_ext = pdf_file_name.split('.pdf')[0]
    input_pdf_images_path = PARSE_DATA_PAGES+pdf_file_name_without_ext+"/"
    create_path(input_pdf_images_path)

    input_images_blocks_path = PARSE_DATA_BLOCKS+pdf_file_name_without_ext+"/"
    create_path(input_images_blocks_path)
    
    if os.path.exists(PARSE_DATA_CSVS+pdf_file_name_without_ext+".csv"):
        print(pdf_file_name_without_ext+".csv", "already exists")
        continue
            
    #convert pdf into bunch of images
    try:
        pdf_2_images_list = pdf_to_img(state_pdfs_path+pdf_file_name, input_pdf_images_path,dpi=500)
    except:
        continue
    
    #sort pages for looping
    input_images = os.listdir(input_pdf_images_path)
    sort_nicely(input_images)
    
    #empty intial data
    df = pd.DataFrame(columns = COLUMNS)
    order_problem = []
    
    amend_page = False
    a_n,b_n,c_n,d_n = "","","",""
    
    #for each page, parse the data
    for page in input_images:
    
        page_full_path = input_pdf_images_path+page
        
        #extract first page content
        if page == '1.jpg':
            first_page_list = extract_first_page_details(page_full_path)
            continue 
            

        #ingnore 2nd page and last page
        if page == '2.jpg':
            continue
            
        if input_images[-1] == page:
            page_full_path = input_pdf_images_path+page
            img = Image.open(page_full_path)
            
            crop_path = input_images_blocks_path+"page/"
            create_path(crop_path)
                        
            a,b,c,d = 2843,1377,950,183  # stats for male and female
            a_n,b_n,c_n,d_n = get_stats(a,b,c,d,img,crop_path)
            break
        
        #loop from 3 page onwards
        if page.endswith('.jpg'):
            
            final_invidual_blocks = []
            blocks_path = input_images_blocks_path+"blocks/"
            create_path(blocks_path)

            page_idx = page.split(".jpg")[0] + "/"
            page_blocks_path = blocks_path+page_idx
            create_path(page_blocks_path)
            
            if page == '3.jpg':
                generate_poll_blocks_from_page(page_full_path,page_blocks_path,amend_page, 484)
            else:
                
                generate_poll_blocks_from_page(page_full_path,page_blocks_path,amend_page, 444)
            
            sorted_blocks = os.listdir(page_blocks_path)
            sort_nicely(sorted_blocks)
            
            for jpg_file in sorted_blocks:
                
                if jpg_file.endswith('.jpg') :

                    text = (pytesseract.image_to_string(page_blocks_path+jpg_file, config='--psm 6', lang='eng+tam')) #config='--psm 4' config='-c preserve_interword_spaces=1'
                    params_list = text.split('\n')
                    new_params_list = [ i for i in params_list if i!='' and i!='\x0c']
                    
                    if len(new_params_list) ==5 or len(new_params_list) == 6:
                        final_invidual_blocks.append(new_params_list)
                    else:
                        order_problem.append((page, jpg_file,new_params_list))    

        
        #put the data into dataframe
        for block in final_invidual_blocks:
            block_list = extract_details_from_block(block)
            
            final_list = arrange_columns(first_page_list,block_list,pdf_file_name_without_ext,a_n,b_n,c_n,d_n)
            
            df_length = len(df)
            df.loc[df_length] = final_list
        
        print("page done : ",page)
                
    #save the dataframe(pdf) data into csv
    save_to_csv(df,PARSE_DATA_CSVS+pdf_file_name_without_ext+".csv")
    print("CSV saved")
    print()
# Out:
# dt3_ac036_ac036205.pdf
# page done :  3.jpg
# page done :  4.jpg
# page done :  5.jpg
# page done :  6.jpg
# page done :  7.jpg
# page done :  8.jpg
# page done :  9.jpg
# page done :  10.jpg
# page done :  11.jpg
# page done :  12.jpg
# page done :  13.jpg
# page done :  14.jpg
# page done :  15.jpg
# page done :  16.jpg
# page done :  17.jpg
# page done :  18.jpg
# CSV saved

# %%
#combine all state files into one csv
combine_all_csvs("tamilnadu_final.csv",PARSE_DATA_CSVS)
