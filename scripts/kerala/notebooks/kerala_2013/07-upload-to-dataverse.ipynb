# %%
#!pip install pyDataverse

# %%
# FIXME: workaround to make it work on cluster server.
import sys
sys.path.append('/home/t-9adar/.conda/envs/env38/lib/python3.8/site-packages')

# %%
# Dataverse API Token
# https://dataverse.harvard.edu/dataverseuser.xhtml?selectTab=apiTokenTab
host = 'https://dataverse.harvard.edu'
token = '<API TOKEN>'
doi = 'doi:10.7910/DVN/MUEGDT'

# %%
from pyDataverse.api import Api

# %%
api = Api('https://dataverse.harvard.edu/', token)
api.status
# Out:
# 'OK'

# %%
resp = api.get_dataset(doi)
resp.json()
# Out:
# {'status': 'OK',
#  'data': {'id': 3108394,
#   'identifier': 'DVN/MUEGDT',
#   'persistentUrl': 'https://doi.org/10.7910/DVN/MUEGDT',
#   'protocol': 'doi',
#   'authority': '10.7910',
#   'publisher': 'Harvard Dataverse',
#   'publicationDate': '2018-03-17',
#   'storageIdentifier': 's3://10.7910/DVN/MUEGDT',
#   'latestVersion': {'id': 335451,
#    'datasetId': 3108394,
#    'datasetPersistentId': 'doi:10.7910/DVN/MUEGDT',
#    'storageIdentifier': 's3://10.7910/DVN/MUEGDT',
#    'versionState': 'DRAFT',
#    'UNF': 'UNF:6:Jul7B4cP7aiLbKdAC1sM5g==',
#    'lastUpdateTime': '2022-11-13T02:26:19Z',
#    'createTime': '2022-11-09T22:41:21Z',
#    'license': {'name': 'CC0 1.0',
#     'uri': 'http://creativecommons.org/publicdomain/zero/1.0'},
# ...

# %%
from glob import glob

for fn in glob('/share/svasudevan2lab/gs-delhi/parse_unsearchable_rolls/data/out/kerala_2013.csv.gz'):
    print(fn)
    resp = api.upload_file(doi, fn)
    print(resp)
# Out:
# /share/svasudevan2lab/gs-delhi/parse_unsearchable_rolls/data/out/kerala_2013.csv.gz
# {'status': 'OK', 'data': {'files': [{'description': '', 'label': 'kerala_2013.csv.gz', 'restricted': False, 'version': 1, 'datasetVersionId': 335451, 'dataFile': {'id': 6708561, 'persistentId': '', 'pidURL': '', 'filename': 'kerala_2013.csv.gz', 'contentType': 'application/gzip', 'filesize': 576075541, 'description': '', 'storageIdentifier': 's3://dvn-cloud:18476990892-1d1651b920b2', 'rootDataFileId': -1, 'md5': '6b4d743e0f8bb051ce4ee845179f9edb', 'checksum': {'type': 'MD5', 'value': '6b4d743e0f8bb051ce4ee845179f9edb'}, 'creationDate': '2022-11-14'}}]}}
