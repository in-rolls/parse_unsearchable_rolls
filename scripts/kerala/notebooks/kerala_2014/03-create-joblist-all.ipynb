# %%
import os
from glob import glob

# %%
N = 280
state = 'kerala'
YEAR = 2014

# %%
for i in range(1, N + 1):
    cmd = """python scripts/{0:s}/{0:s}_{2:d}.py data/part{1:d}/
""".format(state, i, YEAR)
    print(cmd)
    path = '../../parse_unsearchable_rolls/scripts/{0:s}/joblist_{2:d}/{0:s}{1:d}.sh'.format(state, i, YEAR)
    with open(path, 'w') as f:
        f.write(cmd)
    os.chmod(path, 0o755)
# Out:
# python scripts/kerala/kerala_2014.py data/part1/
#
# python scripts/kerala/kerala_2014.py data/part2/
#
# python scripts/kerala/kerala_2014.py data/part3/
#
# python scripts/kerala/kerala_2014.py data/part4/
#
# python scripts/kerala/kerala_2014.py data/part5/
#
# python scripts/kerala/kerala_2014.py data/part6/
#
# python scripts/kerala/kerala_2014.py data/part7/
#
# python scripts/kerala/kerala_2014.py data/part8/
#
# python scripts/kerala/kerala_2014.py data/part9/
#
# python scripts/kerala/kerala_2014.py data/part10/
#
# python scripts/kerala/kerala_2014.py data/part11/
#
# python scripts/kerala/kerala_2014.py data/part12/
#
# python scripts/kerala/kerala_2014.py data/part13/
#
# python scripts/kerala/kerala_2014.py data/part14/
#
# python scripts/kerala/kerala_2014.py data/part15/
#
# python scripts/kerala/kerala_2014.py data/part16/
#
# python scripts/kerala/kerala_2014.py data/part17/
#
# python scripts/kerala/kerala_2014.py data/part18/
#
# ...
